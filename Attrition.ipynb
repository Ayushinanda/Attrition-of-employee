# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushinanda/Attrition-of-employee/blob/main/Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Employee Attrition

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Attrition Data Analytics.csv')
data.head()
# Out:
#    EmployeeNumber  Attrition  Age     BusinessTravel              Department  \
# 0               1          1   41      Travel_Rarely                   Sales
# 1               2          0   49  Travel_Frequently  Research & Development
# 2               3          1   37      Travel_Rarely  Research & Development
# 3               4          0   33  Travel_Frequently  Research & Development
# 4               5          0   27      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  NumCompaniesWorked  OverTime PercentSalaryHike  \
# ...

# %%
data.shape
# Out:
# (1470, 27)

# %%
data.describe()
# Out:
#        EmployeeNumber    Attrition          Age  DistanceFromHome  \
# count     1470.000000  1470.000000  1470.000000       1470.000000
# mean       735.500000     0.161224    36.923810          9.192517
# std        424.496761     0.367863     9.135373          8.106864
# min          1.000000     0.000000    18.000000          1.000000
# 25%        368.250000     0.000000    30.000000          2.000000
# 50%        735.500000     0.000000    36.000000          7.000000
# 75%       1102.750000     0.000000    43.000000         14.000000
# max       1470.000000     1.000000    60.000000         29.000000
#
#          Education  EnvironmentSatisfaction  JobInvolvement     JobLevel  \
# count  1470.000000              1470.000000     1470.000000  1470.000000
# mean      2.912925                 2.721769        2.729932     2.063946
# std       1.024165                 1.093082        0.711561     1.106940
# min       1.000000                 1.000000        1.000000     1.000000
# ...

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9d7c021d7937> in <module>()
#       1
# ----> 2 plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
#       3
#
# NameError: name 'attrition_count' is not defined

# %%
sns.countplot(data['Attrition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data=data.drop([ 'EmployeeNumber'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
for column in data.columns:
    if data[column].dtype==np.number:
        continue
    else:
        data[column]=LabelEncoder().fit_transform(data[column])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.head()
# Out:
#    Attrition  Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0          1   23               2           2                 0          1
# 1          0   31               1           1                 7          0
# 2          1   19               2           1                 1          1
# 3          0   15               1           1                 2          3
# 4          0    9               2           1                 1          0
#
#    EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  ...  \
# 0               1                        1       0               2  ...
# 1               1                        2       1               1  ...
# 2               4                        3       1               1  ...
# 3               1                        3       0               2  ...
# 4               3                        0       1               2  ...
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
#Get Target data 
y = data['Attrition']

#Load X Variables into a Pandas Dataframe with columns 
X = data.drop(['Attrition'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %% [markdown]
# # Building Random Forest Model

# %%
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [2,4]
min_samples_split = [2, 5]
min_samples_leaf = [1, 2]
bootstrap = [True, False]

# %%
param_grid = {
# Number of trees in random forest
    'n_estimators': n_estimators,
# Number of features to consider at every split
    'max_features': max_features,
# Maximum number of levels in tree
    'max_depth': max_depth,
# Minimum number of samples required to split a node
    'min_samples_split': min_samples_split,
# Minimum number of samples required at each leaf node
     'min_samples_leaf': min_samples_leaf,
# Method of selecting samples for training each tree
    'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72, 80], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 4], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
from sklearn.ensemble import RandomForestClassifier
rf_Model =RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf_Model, param_grid = param_grid, cv = 3, verbose=2, n_jobs = 4)

# %%
rf_Grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72,
#                                           80]},
#              verbose=2)

# %%
rf_Grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 41}

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0,)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
rf.score(X_train, y_train)
# Out:
# 0.9795918367346939

# %%
pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, pred)
# Out:
# 0.8469387755102041

# %%
factors = pd.DataFrame(rf.feature_importances_,index= X_train.columns, columns=['Feacture_Importance']).sort_values('Feacture_Importance',ascending=False)
factors
# Out:
#                           Feacture_Importance
# Age                                  0.095769
# MonthlyIncome                        0.095359
# MonthlyRate                          0.070720
# DistanceFromHome                     0.064192
# NumCompaniesWorked                   0.055499
# YearsWithCurrManager                 0.054059
# OverTime                             0.052121
# YearsInCurrentRole                   0.048673
# EnvironmentSatisfaction              0.041774
# Training Times Last Year             0.041382
# PercentSalaryHike                    0.036724
# JobSatisfaction                      0.036121
# JobLevel                             0.034254
# JobRole                              0.033264
# YearsSinceLastPromotion              0.030143
# JobInvolvement                       0.028597
# MaritalStatus                        0.028391
# Stock Option Level                   0.027227
# RelationshipSatisfaction             0.027021
# ...

# %% [markdown]
# # **Roc Curve Obtained**

# %%
y_pred_proba = rf.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()
